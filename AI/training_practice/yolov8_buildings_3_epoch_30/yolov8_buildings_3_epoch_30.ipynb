# %%
import yaml

# %%
# 커스텀 yaml 파일 생성
# yamle 파일은 트레이닝 데이터와 테스트 데이터의 메타 데이터 정보를 가지고 있다.

data = { 'train' : r'\Users\YoungHan\Desktop\yolov8\building\train\images',
         'val' : r'\Users\YoungHan\Desktop\yolov8\building\valid\images',
         'test' : r'\Users\YoungHan\Desktop\yolov8\building\test\images',
         'names' : ['b105', 'b107', 'b108'],
         'nc' : 3 }

with open(r'\Users\YoungHan\Desktop\yolov8\building\building_yaml.yaml', 'w') as f:
    yaml.dump(data, f)

with open(r'\Users\YoungHan\Desktop\yolov8\building\building_yaml.yaml', 'r') as f:
    building_yaml = yaml.safe_load(f)
    display(building_yaml)
# Out:
# {'names': ['b105', 'b107', 'b108'],
#  'nc': 3,
#  'test': '\\Users\\YoungHan\\Desktop\\yolov8\\building\\test\\images',
#  'train': '\\Users\\YoungHan\\Desktop\\yolov8\\building\\train\\images',
#  'val': '\\Users\\YoungHan\\Desktop\\yolov8\\building\\valid\\images'}

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.143  Python-3.11.3 torch-2.0.1 CPU (12th Gen Intel Core(TM) i5-12450H)
# Setup complete  (12 CPUs, 15.6 GB RAM, 253.8/476.2 GB disk)

# %%
# 사전 학습 모델 다운로드
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
# 전이 학습
model.train(data=r'\Users\YoungHan\Desktop\yolov8\building\building_yaml.yaml', epochs=30)
# Out:
# Ultralytics YOLOv8.0.143  Python-3.11.3 torch-2.0.1 CPU (12th Gen Intel Core(TM) i5-12450H)
# ...

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 3
# {0: 'b105', 1: 'b107', 2: 'b108'}

# %%
results = model.predict(source=r'\Users\YoungHan\Desktop\yolov8\building\test\images', save=True)
# Out:
# image 1/40 C:\Users\YoungHan\Desktop\yolov8\building\test\images\009_000011_jpg.rf.f70f4a94b02d69271a78cb9cd86600ab.jpg: 640x640 1 b105, 91.1ms
# image 2/40 C:\Users\YoungHan\Desktop\yolov8\building\test\images\010_000002_jpg.rf.f1e17a8ef3a9f6ab2945f41b3b178fa7.jpg: 640x640 1 b105, 87.5ms
# image 3/40 C:\Users\YoungHan\Desktop\yolov8\building\test\images\010_000023_jpg.rf.fd62f4019cfc18bcb7352623f4d3fbac.jpg: 640x640 1 b105, 91.9ms
# image 4/40 C:\Users\YoungHan\Desktop\yolov8\building\test\images\011_000018_jpg.rf.647d225dfc8a2034dea5ff52d1cd62ce.jpg: 640x640 1 b105, 86.0ms
# image 5/40 C:\Users\YoungHan\Desktop\yolov8\building\test\images\012_000018_jpg.rf.fe48f022ed3d95d8e6e3a1856d2393bd.jpg: 640x640 1 b105, 84.4ms
# image 6/40 C:\Users\YoungHan\Desktop\yolov8\building\test\images\013_000026_jpg.rf.55b152404c45f062ec8f3d1cddd769e9.jpg: 640x640 1 b105, 83.0ms
# ...

# %%
print(type(results), len(results))
# Out:
# <class 'list'> 40

# %%
import numpy as np

detected_num = 0

for result in results:
    
    uniq, cnt = np.unique(result.boxes.cls.cpu().numpy(), return_counts=True)
    uniq_cnt_dict = dict(zip(uniq, cnt))
    
    print('\n{class num:counts} =', uniq_cnt_dict, '\n')
    
    if uniq != None:
        detected_num += 1
    
    for c in result.boxes.cls:
        print('class num=', int(c), ' , class_name =', model.names[int(c)])
# Out:
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {2.0: 1}
#
# class num= 2  , class_name = b108
#
# {class num:counts} = {2.0: 1}
#
# ...

# %%
import glob

detetced_image_list = glob.glob((r'\Users\YoungHan\Desktop\yolov8\runs\detect\predict14\*'))

detected_image_nums = len(detetced_image_list)


print('Test Data Num : ', len(results))

print('Detected Num : ', detected_num)

print('Accuracy : ', detected_num/len(results))

# print(detetced_image_list)
# Out:
# Test Data Num :  40
# Detected Num :  39
# Accuracy :  0.975
