# %%
import yaml

# %%
# 커스텀 yaml 파일 생성
# yamle 파일은 트레이닝 데이터와 테스트 데이터의 메타 데이터 정보를 가지고 있다.

data = { 'train' : '/Users/younghan/Desktop/AndroidProjects/buildings_12/train/images',
         'val' : '/Users/younghan/Desktop/AndroidProjects/buildings_12/valid/images',
         'test' : '/Users/younghan/Desktop/AndroidProjects/buildings_12/test/images',
         'names' : ['b105', 'b107', 'b108', 'b201', 'b205', 'b206', 'b207', 'b208', 'b303', 'b306', 'b311', 'b312'],
         'nc' : 12 }

with open('/Users/younghan/Desktop/AndroidProjects/buildings_12/buildings_12_yaml.yaml', 'w') as f:
    yaml.dump(data, f)

with open('/Users/younghan/Desktop/AndroidProjects/buildings_12/buildings_12_yaml.yaml', 'r') as f:
    building_yaml = yaml.safe_load(f)
    display(building_yaml)
# Out:
# {'names': ['b105',
#   'b107',
#   'b108',
#   'b201',
#   'b205',
#   'b206',
#   'b207',
#   'b208',
#   'b303',
#   'b306',
#   'b311',
#   'b312'],
#  'nc': 12,
#  'test': '/Users/younghan/Desktop/AndroidProjects/buildings_12/test/images',
#  'train': '/Users/younghan/Desktop/AndroidProjects/buildings_12/train/images',
#  'val': '/Users/younghan/Desktop/AndroidProjects/buildings_12/valid/images'}

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.12 torch-2.0.1 CPU (Apple M1 Pro)
# Setup complete ✅ (10 CPUs, 16.0 GB RAM, 142.8/926.4 GB disk)

# %%
# 사전 학습 모델 다운로드
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
# 전이 학습
model.train(data='/Users/younghan/Desktop/AndroidProjects/buildings_12/buildings_12_yaml.yaml', epochs=30)
# Out:
# New https://pypi.org/project/ultralytics/8.0.147 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.12 torch-2.0.1 CPU (Apple M1 Pro)
# ...

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 12
# {0: 'b105', 1: 'b107', 2: 'b108', 3: 'b201', 4: 'b205', 5: 'b206', 6: 'b207', 7: 'b208', 8: 'b303', 9: 'b306', 10: 'b311', 11: 'b312'}

# %%
results = model.predict(source='/Users/younghan/Desktop/AndroidProjects/buildings_12/test/images', save=True)
# Out:
# image 1/140 /Users/younghan/Desktop/AndroidProjects/buildings_12/test/images/s_b105_01_jpg.rf.dd58bdbdd6ba10579b23151e279d94b9.jpg: 640x640 1 b105, 217.6ms
# image 2/140 /Users/younghan/Desktop/AndroidProjects/buildings_12/test/images/s_b105_02_jpg.rf.9596696178a19e62e925300fc9cb32bb.jpg: 640x640 1 b105, 105.6ms
# image 3/140 /Users/younghan/Desktop/AndroidProjects/buildings_12/test/images/s_b105_03_jpg.rf.5b32a85594574e3425212a96a628b196.jpg: 640x640 1 b105, 96.1ms
# image 4/140 /Users/younghan/Desktop/AndroidProjects/buildings_12/test/images/s_b105_04_jpg.rf.f42e4e2a2ad6146de55c4c04c87c6093.jpg: 640x640 1 b105, 151.9ms
# image 5/140 /Users/younghan/Desktop/AndroidProjects/buildings_12/test/images/s_b105_05_jpg.rf.95be73be1b76b624c60ed8a2b70aee85.jpg: 640x640 1 b105, 108.4ms
# image 6/140 /Users/younghan/Desktop/AndroidProjects/buildings_12/test/images/s_b105_06_jpg.rf.07a34e038aa2c2ec3dc181d968da9523.jpg: 640x640 1 b105, 161.6ms
# ...

# %%
print(type(results), len(results))
# Out:
# <class 'list'> 140

# %%
import numpy as np

detected_num = 0

for result in results:
    
    uniq, cnt = np.unique(result.boxes.cls.cpu().numpy(), return_counts=True)
    uniq_cnt_dict = dict(zip(uniq, cnt))
    
    print('\n{class num:counts} =', uniq_cnt_dict, '\n')
    
    if uniq is not None and uniq.size > 0 and len(set(uniq)) == 1:
        detected_num += 1
    
    for c in result.boxes.cls:
        print('class num=', int(c), ' , class_name =', model.names[int(c)])
# Out:
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {0.0: 1}
#
# class num= 0  , class_name = b105
#
# {class num:counts} = {1.0: 1}
#
# class num= 1  , class_name = b107
#
# {class num:counts} = {1.0: 1}
#
# ...

# %%
import glob

detetced_image_list = glob.glob((r'\Users\YoungHan\Desktop\yolov8\runs\detect\predict9\*'))

detected_image_nums = len(detetced_image_list)


print('Test Data Num : ', len(results))

print('Detected Num : ', detected_num)

print('Accuracy : ', detected_num/len(results))

# print(detetced_image_list)
# Out:
# Test Data Num :  140
# Detected Num :  137
# Accuracy :  0.9785714285714285
